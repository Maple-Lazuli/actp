# %%
msg1 = b"0e1b140e0901021104040b2e00100a0e061d17361e041609162c050e1e39150e011a0e18060b060f"
msg2 = b"2157181c01054e1a0a034e1717141b59453717081c450f1f440703044a0b0c011649121e180310005a"
msg3 = b"261802493b510f1945150b121d180c572114131d064946180c164b050f15111d1d101c0554001352030901080315"

# %%
lines = []
for i in range(0, 65535):
    d1 = "".join([chr((i^b)) for b in msg1[::2]])
    d2 = "".join([chr((i^b)) for b in msg2[::2]])
    d3 = "".join([chr((i^b)) for b in msg3[::2]])
    lines.append(d1)
    lines.append(d2)
    lines.append(d3)

# %%
lines
# Out:
# ['0110000100020100011310101200131001010000',
#  '25110041004111154310140140004000141110105',
#  '2104350141011105211104410140011111105015000001',
#  '1001111011131011100201010311020110101111',
#  '34001150115000045201051051115111050001014',
#  '3015241050100014300015501051100000014104111110',
#  '2332222322202322233132323022313223232222',
#  '07332263226333376132362362226222363332327',
#  '0326172363233327033326632362233333327237222223',
#  '3223333233313233322023232133202332323333',
#  '16223372337222267023273273337333272223236',
#  '1237063272322236122237723273322222236326333332',
#  '4554444544464544455754545644575445454444',
#  '61554405440555510754504504440444505554541',
#  '6540714505455541655540054504455555541451444445',
#  '5445555455575455544645454755464554545555',
#  '70445514551444401645415415551555414445450',
#  '7451605414544450744451145415544444450540555554',
#  '6776666766646766677576767466757667676666',
#  '43776627662777732576726726662666727776763',
# ...

# %%
2**16
# Out:
# 65536
